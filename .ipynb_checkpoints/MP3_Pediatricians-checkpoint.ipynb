# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
file_name = r"MP3_list_no_coma33.csv"

df = pd.read_csv(file_name, sep=",")

# %%
df
# Out:
#     LAST NAME  FIRST NAME                                     SPECIALTY  \
# 0    ABRAMYAN     MIKAYEL                            PEDIATRICS GENERAL
# 1     AGRAWAL       NUPUR  UCLA PEDIATRICS GENERAL / UCLA GENDER HEALTH
# 2    AHMADIAN     NAZANIN                       UCLA PEDIATRICS GENERAL
# 3       ALBAN       BLAKE                       UCLA PEDIATRICS GENERAL
# 4    ANDERSON      MARTIN                       UCLA PEDIATRICS GENERAL
# ..        ...         ...                                           ...
# 149       YEN      MORRIS                            PEDIATRICS GENERAL
# 150     YEUNG    JENNIFER                       UCLA PEDIATRICS GENERAL
# 151        YI     PAULINE                       UCLA PEDIATRICS GENERAL
# 152      YOON  KRISTOPHER                       UCLA PEDIATRICS GENERAL
# 153      ZHOU       HELEN                               UCLA PEDIATRICS
#
#                                             GROUP NAME  \
# 0                          PEDIATRIC ASSOC MED GRP INC
# 1    UCLA HEALTH SANTA MONICA MEDICINE PEDIATRICS C...
# 2                     UCLA HEALTH CALABASAS PEDIATRICS
# 3              UCLA HEALTH WEST LOS ANGELES PEDIATRICS
# 4                        UCLA CHILDREN'S HEALTH CENTER
# ..                                                 ...
# 149                           SANTA CLARITA PEDIATRICS
# 150  UCLA HEALTH BRENTWOOD INTERNAL MEDICINE AND PE...
# 151             UCLA HEALTH BEVERLY HILLS BRIGHTON WAY
# 152  UCLA HEALTH SANTA MONICA MEDICINE PEDIATRICS C...
# 153                      UCLA CHILDREN'S HEALTH CENTER
#
#                                                ADDRESS       PHONE
# 0                4330 FULTON AVE SHERMAN OAKS CA 91423  8187841102
# 1     1245 16TH STREET SUITE 125 SANTA MONICA CA 90404  3103158900
# 2    26585 WEST AGOURA ROAD SUITE 360 CALABASAS CA ...  8185922320
# 3        11318 NATIONAL BOULEVARD LOS ANGELES CA 90064  3102319150
# 4    200 UCLA MEDICAL PLAZA SUITE 265 LOS ANGELES C...  3108250867
# ..                                                 ...         ...
# 149      23823 VALENCIA BLVD STE 120 VALENCIA CA 91355  6612534971
# 150  11980 SAN VICENTE BOULEVARD SUITE 102 LOS ANGE...  3102087777
# 151  9675 BRIGHTON WAY SUITE 100 BEVERLY HILLS CA 9...  3102057310
# 152   1245 16TH STREET SUITE 125 SANTA MONICA CA 90404  3103158900
# 153                   200 UCLA MEDICAL PLAZA SUITE 265  3108250867
#
# [154 rows x 6 columns]

# %%
# Import the geocoding tool
from geopandas.tools import geocode

# Geocode addresses using Nominatim. Remember to provide a custom "application name" in the user_agent parameter!
geo2 = geocode(df['ADDRESS'], provider='arcgis', user_agent='autogis_9999', timeout=4)

# %%
geo2
# Out:
#                         geometry  \
# 0    POINT (-118.42216 34.14958)
# 1    POINT (-118.48546 34.02748)
# 2    POINT (-118.70374 34.14301)
# 3    POINT (-118.43219 34.02580)
# 4    POINT (-118.44705 34.06513)
# ..                           ...
# 149  POINT (-118.55259 34.41392)
# 150  POINT (-118.47208 34.05190)
# 151  POINT (-118.40544 34.06779)
# 152  POINT (-118.48546 34.02748)
# 153  POINT (-118.44636 34.06511)
#
#                                                address
# 0     4330 Fulton Ave, Sherman Oaks, California, 91423
# 1    1245 16th St, Ste 125, Santa Monica, Californi...
# 2    26585 Agoura Rd, #360, Calabasas, California, ...
# 3    11318 National Blvd, Los Angeles, California, ...
# 4    200 Ucla Medical Plz, #265, Los Angeles, Calif...
# ..                                                 ...
# 149  23823 Valencia Blvd, Ste 120, Valencia, Califo...
# 150  11980 San Vicente Blvd, Ste 102, Los Angeles, ...
# 151  9675 Brighton Way, #100, Beverly Hills, Califo...
# 152  1245 16th St, Ste 125, Santa Monica, Californi...
# 153                                 UCLA Medical Plaza
#
# [154 rows x 2 columns]

# %%
joined = df.join(geo2)

# %%
joined
# Out:
#     LAST NAME  FIRST NAME                                     SPECIALTY  \
# 0    ABRAMYAN     MIKAYEL                            PEDIATRICS GENERAL
# 1     AGRAWAL       NUPUR  UCLA PEDIATRICS GENERAL / UCLA GENDER HEALTH
# 2    AHMADIAN     NAZANIN                       UCLA PEDIATRICS GENERAL
# 3       ALBAN       BLAKE                       UCLA PEDIATRICS GENERAL
# 4    ANDERSON      MARTIN                       UCLA PEDIATRICS GENERAL
# ..        ...         ...                                           ...
# 149       YEN      MORRIS                            PEDIATRICS GENERAL
# 150     YEUNG    JENNIFER                       UCLA PEDIATRICS GENERAL
# 151        YI     PAULINE                       UCLA PEDIATRICS GENERAL
# 152      YOON  KRISTOPHER                       UCLA PEDIATRICS GENERAL
# 153      ZHOU       HELEN                               UCLA PEDIATRICS
#
#                                             GROUP NAME  \
# 0                          PEDIATRIC ASSOC MED GRP INC
# 1    UCLA HEALTH SANTA MONICA MEDICINE PEDIATRICS C...
# 2                     UCLA HEALTH CALABASAS PEDIATRICS
# 3              UCLA HEALTH WEST LOS ANGELES PEDIATRICS
# 4                        UCLA CHILDREN'S HEALTH CENTER
# ..                                                 ...
# 149                           SANTA CLARITA PEDIATRICS
# 150  UCLA HEALTH BRENTWOOD INTERNAL MEDICINE AND PE...
# 151             UCLA HEALTH BEVERLY HILLS BRIGHTON WAY
# 152  UCLA HEALTH SANTA MONICA MEDICINE PEDIATRICS C...
# 153                      UCLA CHILDREN'S HEALTH CENTER
#
#                                                ADDRESS       PHONE  \
# 0                4330 FULTON AVE SHERMAN OAKS CA 91423  8187841102
# 1     1245 16TH STREET SUITE 125 SANTA MONICA CA 90404  3103158900
# 2    26585 WEST AGOURA ROAD SUITE 360 CALABASAS CA ...  8185922320
# 3        11318 NATIONAL BOULEVARD LOS ANGELES CA 90064  3102319150
# 4    200 UCLA MEDICAL PLAZA SUITE 265 LOS ANGELES C...  3108250867
# ..                                                 ...         ...
# 149      23823 VALENCIA BLVD STE 120 VALENCIA CA 91355  6612534971
# 150  11980 SAN VICENTE BOULEVARD SUITE 102 LOS ANGE...  3102087777
# 151  9675 BRIGHTON WAY SUITE 100 BEVERLY HILLS CA 9...  3102057310
# 152   1245 16TH STREET SUITE 125 SANTA MONICA CA 90404  3103158900
# 153                   200 UCLA MEDICAL PLAZA SUITE 265  3108250867
#
#                         geometry  \
# 0    POINT (-118.42216 34.14958)
# 1    POINT (-118.48546 34.02748)
# 2    POINT (-118.70374 34.14301)
# 3    POINT (-118.43219 34.02580)
# 4    POINT (-118.44705 34.06513)
# ..                           ...
# 149  POINT (-118.55259 34.41392)
# 150  POINT (-118.47208 34.05190)
# 151  POINT (-118.40544 34.06779)
# 152  POINT (-118.48546 34.02748)
# 153  POINT (-118.44636 34.06511)
#
#                                                address
# 0     4330 Fulton Ave, Sherman Oaks, California, 91423
# 1    1245 16th St, Ste 125, Santa Monica, Californi...
# 2    26585 Agoura Rd, #360, Calabasas, California, ...
# 3    11318 National Blvd, Los Angeles, California, ...
# 4    200 Ucla Medical Plz, #265, Los Angeles, Calif...
# ..                                                 ...
# 149  23823 Valencia Blvd, Ste 120, Valencia, Califo...
# 150  11980 San Vicente Blvd, Ste 102, Los Angeles, ...
# 151  9675 Brighton Way, #100, Beverly Hills, Califo...
# 152  1245 16th St, Ste 125, Santa Monica, Californi...
# 153                                 UCLA Medical Plaza
#
# [154 rows x 8 columns]

# %%
joined.to_csv("MP3_Ped_Geocoded.csv")

# %%
gdf = gpd.GeoDataFrame(
    joined)

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 fiona.help
#
# NameError: name 'fiona' is not defined

# %%
gdf.to_file('test.shp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 gdf.to_file('test.shp')
#
# NameError: name 'gdf' is not defined
